# %% [markdown]
# ### 🏢 Desafio: Sistema de Cadastro de Funcionários com Listas e Loop for
#
# 📌 Contexto do Desafio
#
# Você foi contratado(a) pela **MSCorp** para desenvolver um sistema de cadastro de funcionários usando listas. O programa deve:
#
# ✅ Cadastrar alguns funcionários (quantos o usuário quiser)
#
# ✅ Armazenar nome, cargo e salário de cada um em listas separadas.
#
# ✅ No final, exibir um relatório organizado com todos os dados.

# %% [markdown]
# ### 📋 Requisitos do Sistema
#
#
# 1️⃣ Estrutura dos Dados
# Usaremos 3 listas separadas para armazenar os dados:

# %%
nomes = []
cargos = []
salarios = []

# %% [markdown]
# 2️⃣ Fluxo do Programa
#
#
# O sistema pergunta: "Quantos funcionários deseja cadastrar?"
#
# Usando um loop for, o programa repete o cadastro N vezes
#
# Para cada funcionário, coletar:
#
# 📛 Nome completo
#
# 💼 Cargo
#
# 💵 Salário (aceitar decimais, ex: 3500.50)
#
# Ao final, exibir todos os funcionários cadastrados em formato de tabela

# %% [markdown]
# ### 🎯 Exemplo de Saída

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Meu Código:

# %%
# Listas para armazenar os dados 
nomes = []
cargos = []
salarios = []

funcionarios = []

quantidade = int(input("Quantos funcionários deseja cadastrar? "))

for i in range(1, quantidade + 1):
    print(f"\n📋 Cadastro do {i} funcionário:\n")
    nome = input("\nNome completo:\n")
    cargo = input("\nCargo:\n")
    salario = float(input("\nSalário: R$\n"))

    print(f"Nome Completo: {nome}")
    print(f"Cargo: {cargo}")
    print(f"Salário: {salario}")

    nomes.append(nome)
    cargos.append(cargo)
    salarios.append(salario)
    

print(" **Relatório de funcionários** ")
print("---------------------------------------------------------------------------")
print("Nome                            |Cargo                          |Salário")
print("---------------------------------------------------------------------------")
for i in range(quantidade):
    print(f"{nomes[i]}                          |{cargos[i]}                            |{salarios[i]}")
print("---------------------------------------------------------------------------")
print(f"Total de funcionários cadastrados: {quantidade}")
# Out:
# 📋 Cadastro do 1 funcionário:
#
# Nome Completo: miguel
# Cargo: adm
# Salário: 100.0
#
# 📋 Cadastro do 2 funcionário:
#
# Nome Completo: kaio
# Cargo: adm
# Salário: 100.0
#  **Relatório de funcionários**
# ---------------------------------------------------------------------------
# Nome                            |Cargo                          |Salário
# ---------------------------------------------------------------------------
# miguel                          |adm                            |100.0
# kaio                          |adm                            |100.0
# ---------------------------------------------------------------------------
# Total de funcionários cadastrados: 2

# %%
# Listas para armazenar os dados
nomes = []
cargos = []
salarios = []

quantidade = int(input("Quantos funcionários deseja cadastrar? "))

for i in range(quantidade):
    print(f"\n📝 Cadastro do {i+1}º funcionário:\n")
    nome = input("Nome completo: ").title()
    cargo = input("Cargo: ").capitalize()
    salario = float(input("Salário: R$ "))
    
    # Adiciona os dados às listas
    nomes.append(nome)
    cargos.append(cargo)
    salarios.append(salario)

    print(f"⌨ Nome completo: {nome} \n")
    print(f"💼 Salário : {salario} \n")
    print(f"💵 Cargo : {cargo} \n")

# Exibe o relatório final
print("\n🌟 **Relatório de Funcionários** 🌟")
print("-" * 60)
print(f"{'Nome':<20} | {'Cargo':<20} | {'Salário':>10}")
print("-" * 60)
for i in range(len(nomes)):
    print(f"{nomes[i]:<20} | {cargos[i]:<20} | R$ {salarios[i]:>8.2f}")
print("-" * 60)
print(f"Total de funcionários cadastrados: {len(nomes)}")
# Out:
# 📝 Cadastro do 1º funcionário:
#
# ⌨ Nome completo: Miguel
#
# 💼 Salário : 1500.0
#
# 💵 Cargo : Adm
#
#
# 📝 Cadastro do 2º funcionário:
#
# ⌨ Nome completo: Mateus
#
# 💼 Salário : 1500.0
#
# 💵 Cargo : Professor
#
#
# 🌟 **Relatório de Funcionários** 🌟
# ------------------------------------------------------------
# Nome                 | Cargo                |    Salário
# ------------------------------------------------------------
# Miguel               | Adm                  | R$  1500.00
# Mateus               | Professor            | R$  1500.00
# ------------------------------------------------------------
# Total de funcionários cadastrados: 2

# %% [markdown]
# ### Graficos para impressionar

# %%
import matplotlib.pyplot as plt


# ========== VISUALIZAÇÃO COM MATPLOTLIB ==========

# Configuração do estilo
plt.style.use('ggplot')
plt.figure(figsize=(12, 6))

# Gráfico 1: Distribuição de Salários
plt.subplot(1, 2, 1)
plt.bar(nomes, salarios, color='skyblue')
plt.title('Salários dos Funcionários')
plt.xlabel('Funcionários')
plt.ylabel('Salário (R$)')
plt.xticks(rotation=90)
plt.grid(axis='y')

# Gráfico 2: Distribuição por Cargo (contagem)
plt.subplot(1, 2, 2)
cargos_unicos = list(set(cargos))  # Remove duplicatas
contagem = [cargos.count(cargo) for cargo in cargos_unicos]
plt.pie(contagem, labels=cargos_unicos, autopct='%1.1f%%', colors=['lightcoral', 'lightgreen', 'gold'])
plt.title('Distribuição por Cargo')

plt.tight_layout()
plt.show()

# Gráfico 3: Histograma de Faixas Salariais (extra)
plt.figure(figsize=(8, 5))
faixas = [0, 3000, 5000, 7000, 9000, 11000]
plt.hist(salarios, bins=faixas, edgecolor='black', color='lightseagreen')
plt.title('Distribuição por Faixa Salarial')
plt.xlabel('Faixas Salariais (R$)')
plt.ylabel('Quantidade de Funcionários')
plt.xticks(faixas)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')
